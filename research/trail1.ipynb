# %%
print("hello")
# Out:
# hello

# %%
import os

# %%
pwd
# Out:
# 'c:\\Users\\DELL\\Desktop\\drink_quality_prediction\\research'

# %%
os.chdir('..')

# %%
pwd
# Out:
# 'c:\\Users\\DELL\\Desktop\\drink_quality_prediction'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = 'data\Drinks-data.csv'
df=pd.read_csv(data_path)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.hist(bins = 50 , figsize=(20,15),color = 'orange')
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
df.quality.value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# 240

# %%
X = df.drop(columns=['quality'],axis=1)
y=df.quality

# %%
X_train , X_test , y_train, y_test = train_test_split(X,y,test_size=.20,random_state=42)

# %%
y_test
# Out:
# 55      5
# 1291    6
# 1544    7
# 593     5
# 1261    4
#        ..
# 1086    7
# 662     6
# 279     7
# 1111    7
# 737     6
# Name: quality, Length: 272, dtype: int64

# %%
print("dataframe_size : " , df.shape)
print("X_train :",X_train.shape)
print("X_test",X_test.shape)
print('y_train',y_train.shape)
print('y_test',y_test.shape)
# Out:
# dataframe_size :  (1359, 12)
# X_train : (1087, 11)
# X_test (272, 11)
# y_train (1087,)
# y_test (272,)

# %%
X_train.select_dtypes(include=np.number)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1016            8.9              0.38         0.40             2.2      0.068
# 1519            6.6              0.70         0.08             2.6      0.106
# 452             6.8              0.56         0.03             1.7      0.084
# 847             7.4              0.68         0.16             1.8      0.078
# 58              7.8              0.59         0.18             2.3      0.076
# ...             ...               ...          ...             ...        ...
# 1285           11.3              0.37         0.50             1.8      0.090
# 1329            7.4              0.60         0.26             2.1      0.083
# 1526            6.8              0.47         0.08             2.2      0.064
# 1011            8.9              0.32         0.31             2.0      0.088
# 1322            9.1              0.34         0.42             1.8      0.058
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1016                 12.0                  28.0  0.99486  3.27       0.75
# 1519                 14.0                  27.0  0.99665  3.44       0.58
# 452                  18.0                  35.0  0.99680  3.44       0.63
# 847                  12.0                  39.0  0.99770  3.50       0.70
# 58                   17.0                  54.0  0.99750  3.43       0.59
# ...                   ...                   ...      ...   ...        ...
# 1285                 20.0                  47.0  0.99734  3.15       0.57
# 1329                 17.0                  91.0  0.99616  3.29       0.56
# 1526                 18.0                  38.0  0.99553  3.30       0.65
# 1011                 12.0                  19.0  0.99570  3.17       0.55
# 1322                  9.0                  18.0  0.99392  3.18       0.55
#
#       alcohol
# 1016     12.6
# 1519     10.2
# 452      10.0
# 847       9.9
# 58       10.0
# ...       ...
# 1285     10.5
# 1329      9.8
# 1526      9.6
# 1011     10.4
# 1322     11.4
#
# [1087 rows x 11 columns]

# %%
num_features = X_train.select_dtypes(include=np.number).columns.to_list()

def  detect_outliers_iqr(df):
    outlier_summary ={} 
    
    for col in df.columns:
        Q1 = df[col].quantile(.25)
        Q3 = df[col].quantile(.75)
        IQR = Q3-Q1 
        
        lower_bond =  Q1 - 1.5 * IQR 
        upper_bound = Q3 + 1.5 * IQR
        
        
        outliers = df[ (df[col]<lower_bond)|( df[col]>upper_bound)]
        
        
        outlier_summary[col] = len(outliers)
    
    return pd.DataFrame.from_dict(outlier_summary, orient='index', columns=['Outlier Count'])

        
outlier_report = detect_outliers_iqr(df[num_features])

print(outlier_report.sort_values(by="Outlier Count", ascending=False))
# Out:
#                       Outlier Count
# residual sugar                  126
# chlorides                        87
# sulphates                        55
# total sulfur dioxide             45
# fixed acidity                    41
# density                          35
# pH                               28
# free sulfur dioxide              26
# volatile acidity                 19
# alcohol                          12
# citric acid                       1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 12))
X_train[num_features].boxplot(rot=90)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
plt.figure(figsize=(15, 25))

for i, col in enumerate(num_features, 1):
    plt.subplot(6, 2, i)
    sns.boxplot(x=X[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()



X_train_scaled = pd.DataFrame(
    scaler.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index
)

X_test_scaled = pd.DataFrame(
    scaler.transform(X_test),
    columns=X_test.columns,
    index=X_test.index
)

# %%
plt.figure(figsize=(15, 25))
plt.title("after scaling")

for i, col in enumerate(num_features, 1):
    plt.subplot(6, 2, i)
    sns.boxplot(x=X_train_scaled[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
skewed_cols = [
    'residual sugar',
    'chlorides',
    'free sulfur dioxide',
    'total sulfur dioxide',
    'sulphates'
]

X_train[skewed_cols] = np.log1p(X_train[skewed_cols])
X_test[skewed_cols] = np.log1p(X_test[skewed_cols])

# %%
from sklearn.linear_model import ElasticNet

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# Create pipeline
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=5000))
])

# Train
pipeline.fit(X_train, y_train)

# Extract trained logistic regression model
log_reg = pipeline.named_steps["model"]
print(log_reg.coef_.shape)
print("""So in your case:
6 classes & 11 features""")

# If binary classification
if log_reg.coef_.shape[0] == 1:
    importance = pd.Series(
        log_reg.coef_[0],
        index=X_train.columns
    )

else:
    # Multiclass case → take mean absolute coefficient across classes
    importance = pd.Series(
        np.abs(log_reg.coef_).mean(axis=0),
        index=X_train.columns
    )
    
    

# Sort by importance
importance = importance.sort_values(key=abs, ascending=False)

print(importance)
# Out:
# (6, 11)
# So in your case:
# 6 classes & 11 features
# alcohol                 0.794870
# pH                      0.488160
# volatile acidity        0.477085
# fixed acidity           0.453419
# sulphates               0.443054
# chlorides               0.417893
# residual sugar          0.407074
# total sulfur dioxide    0.390010
# density                 0.316194
# free sulfur dioxide     0.284065
# citric acid             0.265018
# dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

importance = pd.Series(model.feature_importances_, index=X_train.columns)
importance = importance.sort_values(ascending=False)

print(importance)
# Out:
# alcohol                 0.146042
# sulphates               0.108175
# total sulfur dioxide    0.101840
# volatile acidity        0.100800
# density                 0.090780
# chlorides               0.084383
# fixed acidity           0.076126
# residual sugar          0.074590
# pH                      0.073764
# citric acid             0.073675
# free sulfur dioxide     0.069823
# dtype: float64

# %%
y.unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df1 = df.copy()

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# ===============================
# 1️⃣ Load Data
# ===============================

data_path = 'data\\Drinks-data.csv'
df = pd.read_csv(data_path)

print("Original Shape:", df.shape)
print(df.quality.value_counts())

df.drop_duplicates(inplace=True)
print("After removing duplicates:", df.shape)


# ===============================
# 2️⃣ Create Binary Target
# ===============================
# 0 = Bad (3,4,5)
# 1 = Good (6,7,8)

df["quality_binary"] = (df["quality"] >= 6).astype(int)

print("\nBinary Target Distribution:")
print(df["quality_binary"].value_counts())


# ===============================
# 3️⃣ Define X and y
# ===============================

X = df.drop(columns=["quality", "quality_binary"])
y = df["quality_binary"]


# ===============================
# 4️⃣ Train-Test Split (Stratified)
# ===============================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

print("\nTrain/Test Shapes:")
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)


# ===============================
# 5️⃣ Log Transform Skewed Columns
# ===============================

skewed_cols = [
    'residual sugar',
    'chlorides',
    'free sulfur dioxide',
    'total sulfur dioxide',
    'sulphates'
]

X_train[skewed_cols] = np.log1p(X_train[skewed_cols])
X_test[skewed_cols] = np.log1p(X_test[skewed_cols])


# ===============================
# 6️⃣ Logistic Regression (Balanced)
# ===============================

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, ConfusionMatrixDisplay

log_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LogisticRegression(max_iter=5000, class_weight='balanced'))
])

log_pipeline.fit(X_train, y_train)

y_pred_log = log_pipeline.predict(X_test)

print("\n===== Logistic Regression (Binary) =====")
print("Accuracy :", accuracy_score(y_test, y_pred_log))
print("Precision:", precision_score(y_test, y_pred_log))
print("Recall   :", recall_score(y_test, y_pred_log))
print("F1 Score :", f1_score(y_test, y_pred_log))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_log))

ConfusionMatrixDisplay.from_estimator(
    log_pipeline,
    X_test,
    y_test,
    display_labels=["Bad", "Good"],
    cmap="Blues"
)
plt.title("Logistic Regression Confusion Matrix")
plt.show()


# ===============================
# 7️⃣ Random Forest (Balanced)
# ===============================

from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=400,
    max_depth=12,
    min_samples_leaf=2,
    class_weight='balanced',
    random_state=42
)

rf_model.fit(X_train, y_train)

y_pred_rf = rf_model.predict(X_test)

print("\n===== Random Forest (Binary) =====")
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))

ConfusionMatrixDisplay.from_estimator(
    rf_model,
    X_test,
    y_test,
    display_labels=["Bad", "Good"],
    cmap="Greens"
)
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Original Shape: (1599, 12)
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64
# After removing duplicates: (1359, 12)
#
# Binary Target Distribution:
# quality_binary
# 1    719
# 0    640
# Name: count, dtype: int64
#
# Train/Test Shapes:
# X_train: (951, 11)
# X_test : (408, 11)
# y_train: (951,)
# y_test : (408,)
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=5000))])
# ===== Logistic Regression (Binary) =====
# Accuracy : 0.7303921568627451
# Precision: 0.7789473684210526
# Recall   : 0.6851851851851852
# F1 Score : 0.729064039408867
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.78      0.73       192
#            1       0.78      0.69      0.73       216
#
#     accuracy                           0.73       408
#    macro avg       0.73      0.73      0.73       408
# weighted avg       0.74      0.73      0.73       408
# Text(0.5, 1.0, 'Logistic Regression Confusion Matrix')
# RandomForestClassifier(class_weight='balanced', max_depth=12,
#                        min_samples_leaf=2, n_estimators=400, random_state=42)
# ===== Random Forest (Binary) =====
# Accuracy : 0.7818627450980392
# Precision: 0.8256410256410256
# Recall   : 0.7453703703703703
# F1 Score : 0.7834549878345499
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78       192
#            1       0.83      0.75      0.78       216
#
#     accuracy                           0.78       408
#    macro avg       0.78      0.78      0.78       408
# weighted avg       0.79      0.78      0.78       408
# Text(0.5, 1.0, 'Random Forest Confusion Matrix')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import pandas as pd


def evaluate_models(X_train, X_test, y_train, y_test):
    
    models = {
        "Logistic Regression": Pipeline([
            ("scaler", StandardScaler()),
            ("model", LogisticRegression(max_iter=5000, class_weight='balanced'))
        ]),
        
        "Random Forest": RandomForestClassifier(
            n_estimators=400,
            max_depth=12,
            class_weight='balanced',
            random_state=42
        ),
        
        "Gradient Boosting": GradientBoostingClassifier(),
        
        "Extra Trees": ExtraTreesClassifier(
            n_estimators=400,
            random_state=42
        ),
        
        "SVM": Pipeline([
            ("scaler", StandardScaler()),
            ("model", SVC(class_weight='balanced'))
        ]),
        
        "KNN": Pipeline([
            ("scaler", StandardScaler()),
            ("model", KNeighborsClassifier())
        ]),
        
        "Decision Tree": DecisionTreeClassifier(
            class_weight='balanced',
            random_state=42
        ),
        
        "Naive Bayes": GaussianNB()
    }
    
    results = {}
    
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        
        results[name] = {
            "Accuracy": accuracy_score(y_test, y_pred),
            "Precision": precision_score(y_test, y_pred),
            "Recall": recall_score(y_test, y_pred),
            "F1 Score": f1_score(y_test, y_pred)
        }
    
    # Convert to DataFrame
    results_df = pd.DataFrame(results).T
    
    # Sort by F1 Score
    results_df = results_df.sort_values(by="F1 Score", ascending=False)
    
    print("\n===== Top 5 Models (Sorted by F1 Score) =====\n")
    print(results_df.head(5))
    
    return results_df

# %%
results_df = evaluate_models(X_train, X_test, y_train, y_test)
# Out:
# ===== Top 5 Models (Sorted by F1 Score) =====
#
#                      Accuracy  Precision    Recall  F1 Score
# Extra Trees          0.772059   0.786047  0.782407  0.784223
# Random Forest        0.774510   0.816327  0.740741  0.776699
# SVM                  0.752451   0.810811  0.694444  0.748130
# Gradient Boosting    0.737745   0.782383  0.699074  0.738386
# Logistic Regression  0.730392   0.778947  0.685185  0.729064

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, accuracy_score, f1_score
import pandas as pd

import mlflow

mlflow.set_experiment("MLflow Quickstart")


# Enable autologging for scikit-learn
mlflow.sklearn.autolog()

def fine_tune_top_models(X_train, X_test, y_train, y_test):
    
    # -----------------------------
    # Parameter Grids
    # -----------------------------
    
    rf_params = {
        "n_estimators": [300, 500, 800],
        "max_depth": [None, 10, 20, 30],
        "min_samples_split": [2, 5, 10],
        "min_samples_leaf": [1, 2, 4]
    }
    
    et_params = {
        "n_estimators": [300, 500, 800],
        "max_depth": [None, 10, 20, 30],
        "min_samples_split": [2, 5, 10],
        "min_samples_leaf": [1, 2, 4]
    }
    
    # -----------------------------
    # Models
    # -----------------------------
    
    rf = RandomForestClassifier(
        class_weight='balanced',
        random_state=42
    )
    
    et = ExtraTreesClassifier(
        random_state=42
    )
    
    # -----------------------------
    # GridSearch
    # -----------------------------
    
    rf_grid = GridSearchCV(
        rf,
        rf_params,
        cv=5,
        scoring='f1',
        n_jobs=-1
    )
    
    et_grid = GridSearchCV(
        et,
        et_params,
        cv=5,
        scoring='f1',
        n_jobs=-1
    )
    
    print("Tuning Random Forest...")
    rf_grid.fit(X_train, y_train)
    
    print("Tuning Extra Trees...")
    et_grid.fit(X_train, y_train)
    
    # -----------------------------
    # Best Estimators
    # -----------------------------
    
    best_rf = rf_grid.best_estimator_
    best_et = et_grid.best_estimator_
    
    # -----------------------------
    # Evaluate on Test Data
    # -----------------------------
    
    models = {
        "Tuned Random Forest": best_rf,
        "Tuned Extra Trees": best_et
    }
    
    results = {}
    
    for name, model in models.items():
        y_pred = model.predict(X_test)
        
        results[name] = {
            "Accuracy": accuracy_score(y_test, y_pred),
            "F1 Score": f1_score(y_test, y_pred)
        }
        
        print(f"\n{name} Classification Report:")
        print(classification_report(y_test, y_pred))
    
    results_df = pd.DataFrame(results).T
    results_df = results_df.sort_values(by="F1 Score", ascending=False)
    
    print("\n===== Tuned Model Results =====\n")
    print(results_df)
    
    print("\n===== Best Parameters =====\n")
    print("Random Forest:", rf_grid.best_params_)
    print("Extra Trees:", et_grid.best_params_)
    
    return results_df, best_rf, best_et

# %%
results_df, best_rf_model, best_et_model = fine_tune_top_models(
    X_train, X_test, y_train, y_test
)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
def quick_tune_models(X_train, X_test, y_train, y_test):

    with mlflow.start_run():

        rf_params = {
            "n_estimators": [100, 200],
            "max_depth": [None, 10],
            "min_samples_split": [2, 5],
            "min_samples_leaf": [1, 2]
        }

        et_params = {
            "n_estimators": [100, 200],
            "max_depth": [None, 10],
            "min_samples_split": [2, 5],
            "min_samples_leaf": [1, 2]
        }

        rf = RandomForestClassifier(class_weight='balanced', random_state=42)
        et = ExtraTreesClassifier(random_state=42)

        rf_search = RandomizedSearchCV(
            rf, rf_params,
            n_iter=6,
            cv=3,
            scoring='f1',
            n_jobs=-1,
            random_state=42
        )

        et_search = RandomizedSearchCV(
            et, et_params,
            n_iter=6,
            cv=3,
            scoring='f1',
            n_jobs=-1,
            random_state=42
        )

        rf_search.fit(X_train, y_train)
        et_search.fit(X_train, y_train)

        best_rf = rf_search.best_estimator_
        best_et = et_search.best_estimator_

        # Log best params manually
        mlflow.log_params(rf_search.best_params_)
        mlflow.log_metric("rf_best_cv_score", rf_search.best_score_)

        mlflow.log_params({f"et_{k}": v for k, v in et_search.best_params_.items()})
        mlflow.log_metric("et_best_cv_score", et_search.best_score_)

        # Evaluate
        y_pred_rf = best_rf.predict(X_test)
        y_pred_et = best_et.predict(X_test)

        rf_f1 = f1_score(y_test, y_pred_rf)
        et_f1 = f1_score(y_test, y_pred_et)

        mlflow.log_metric("rf_test_f1", rf_f1)
        mlflow.log_metric("et_test_f1", et_f1)

        print("RF Test F1:", rf_f1)
        print("ET Test F1:", et_f1)

        return best_rf, best_et

# %%
quick_tune_models(X_train, X_test, y_train, y_test)
# Out:
# 2026/03/13 00:23:53 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/03/13 00:23:56 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2026/03/13 00:23:57 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/03/13 00:24:00 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2026/03/13 00:24:00 INFO mlflow.sklearn.utils: Logging the 5 best runs, one run will be omitted.
# 2026/03/13 00:24:01 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/03/13 00:24:03 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2026/03/13 00:24:04 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/03/13 00:24:07 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2026/03/13 00:24:07 INFO mlflow.sklearn.utils: Logging the 5 best runs, one run will be omitted.
# 2026/03/13 00:24:07 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID f636c6dab0444734805aef9a4cffcc7b. Failed operations: [MlflowException("Changing param values is not allowed. Params were already logged=\'[{\'key\': \'best_min_samples_split\', \'old_value\': \'2\', \'new_value\': \'5\'}, {\'key\': \'best_max_depth\', \'old_value\': \'None\', \'new_value\': \'10\'}]\' for run ID=\'f636c6dab0444734805aef9a4cffcc7b\'.")]')]
# RF Test F1: 0.784688995215311
# ET Test F1: 0.7684964200477327
# (RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                         random_state=42),
#  ExtraTreesClassifier(max_depth=10, min_samples_split=5, n_estimators=200,
#                       random_state=42))
